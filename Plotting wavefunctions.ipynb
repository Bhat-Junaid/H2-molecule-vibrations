# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# E = -0.9470991E+0

# %%
data1 = np.loadtxt(r"C:\Academics\Numerical Methods\Wavefunction0.txt")
plt.plot(data1[:,0], data1[:,1], label = "$v = 0$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %% [markdown]
# E1 = -0.8456891E+00

# %%
data2 = np.loadtxt(r"C:\Academics\Numerical Methods\Wavefunction1.txt")
plt.plot(data2[:,0], data2[:,1], label = "$v = 1$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %%
Guess_bw_0 = [0.9473, 0.9435, 0.9380, 0.9260, 0.9050, 0.8900, 0.8850, 0.8820]
Guess_bw_1 = [0.8468, 0.8422, 0.8302, 0.8192, 0.8042, 0.7952, 0.7922, 0.7902 ]
Guess_ab_0 = [0.9485,0.9470, 0.9530 ,0.9670 ]
Guess_ab_1 = [0.8502, 0.8510, 0.08630,0.8770]

energy_0 = 0.9473
energy_1 = 0.8468
iter_ab_0 = [1, 2, 3, 4 ]
iter_ab_1 = [1,2 ,3, 4]
iter_0 = [1, 2, 3, 4, 5, 6, 7, 8 ]
iter_1 = [1, 2, 3, 4, 5, 6, 7, 8 ]
dist_0 = []
dist_1 = []
for i in range(len(Guess_bw_0)):
    dist_0.append(abs(energy_0-Guess_bw_0[i]))
for i in range(len(Guess_bw_1)):
    dist_1.append(abs(energy_1-Guess_bw_1[i]))
plt.plot(dist_0, iter_0, marker = 'o',label = '$v = 0$')
plt.plot(dist_1,iter_1, marker = '.' ,label= '$v = 1$')
plt.xlabel("Distance($|E_{exact}-E_{guess}|$)")
plt.ylabel('Number of iterations')
plt.grid(color = "0.9")
plt.minorticks_on()
plt.grid(which='both', linestyle=':', linewidth='0.5', color='gray')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

Guess_bw_0 = [0.9473, 0.9455, 0.9400, 0.9260, 0.9050, 0.8900, 0.8850, 0.8820]
Guess_bw_1 = [0.8468, 0.8402, 0.8302, 0.8192, 0.8042, 0.7952, 0.7922, 0.7902]

energy_0 = 0.9473
energy_1 = 0.8468

dist_0 = [abs(energy_0 - val) for val in Guess_bw_0]
dist_1 = [abs(energy_1 - val) for val in Guess_bw_1]

plt.bar(range(len(dist_0)), dist_0, label='$v = 0$')


plt.xlabel("Number of iteractions")
plt.ylabel('Distance ($|E_{exact} - E_{guess}|$)')
plt.title('Bar Graph of Distances')
plt.legend()
plt.grid(color='grey', alpha = 0.2 )
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
Guess_bw_0 = [0.9473, 0.9435, 0.9380, 0.9260, 0.9050, 0.8900, 0.8850, 0.8820]
Guess_bw_1 = [0.8468, 0.8422, 0.8302, 0.8192, 0.8042, 0.7952, 0.7922, 0.7902]
Guess_ab_0 = [0.9485, 0.9470, 0.9530, 0.9670]
Guess_ab_1 = [0.8502, 0.8510, 0.8630, 0.8770]

energy_0 = 0.9473
energy_1 = 0.8468
iter_ab_0 = [1, 2, 3, 4]
iter_ab_1 = [1, 2, 3, 4]
iter_0 = [1, 2, 3, 4, 5, 6, 7, 8]
iter_1 = [1, 2, 3, 4, 5, 6, 7, 8]

# Creating scatter plot centered around energy_0
plt.figure(figsize=(6, 5))
plt.scatter(Guess_bw_0, iter_0, label='lower guess values')
plt.scatter(Guess_ab_0, iter_ab_0, label='higher guess values')
plt.xlabel('Initial Guess')
plt.ylabel('Iterations')
plt.title(r'Variation of iterations with distance from eigenvalues for $\nu = 0$')
plt.minorticks_on()
plt.grid(which='both', linestyle=':', linewidth='0.5', color='gray')
plt.legend()
plt.show()

# Creating scatter plot centered around energy_1
plt.figure(figsize=(6, 5))
plt.scatter(Guess_bw_1, iter_1, label='lower guess values')
plt.scatter(Guess_ab_1, iter_ab_1, label='Higher guess values')
plt.xlabel('Initial Guess')
plt.ylabel('Iterations')
plt.title(r'Variation of iterations with distance from eigenvalues for $\nu = 1$')
plt.minorticks_on()
plt.grid(which='both', linestyle=':', linewidth='0.5', color='gray')
plt.legend()
plt.show()

# %% [markdown]
# E2 = -0.7499736E+00

# %%
data3 = np.loadtxt(r"C:\Academics\Numerical Methods\Wavefunction2.txt")
plt.plot(data3[:,0], data3[:,1], label = "$v = 2$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %%
# Calculation of the maximum v
a = 1.3924
b = 1.4840e-3
v_max = (1/(a*np.sqrt(b))) - 0.5
print(v_max)
# Out:
# 18.143138884342324

# %% [markdown]
# E3 = -0.6609138E+00

# %%
data4 = np.loadtxt(r"C:\Academics\Numerical Methods\Wavefunction3.txt")
plt.plot(data4[:,0], data4[:,1], label = "$v = 3$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %% [markdown]
# E4 =  -0.5758257E+00

# %%
data5 = np.loadtxt(r"C:\Academics\Numerical Methods\Wavefunction4.txt")
plt.plot(data5[:,0], data5[:,1], label = "$ v = 4$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %% [markdown]
# E5 = -0.4974192E+00

# %%
data6 = np.loadtxt(r"C:\Academics\Numerical Methods\Wavefunction5.txt")
plt.plot(data6[:,0], data6[:,1], label = "$ v = 5$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %% [markdown]
# E6 = -0.4247642E+00

# %%
data7 = np.loadtxt(r"C:\Academics\Numerical Methods\Wavefunction6.txt")
plt.plot(data7[:,0], data7[:,1], label = "$ v = 6$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %% [markdown]
# E7 = -0.3577143E+00

# %%
data8 = np.loadtxt(r"C:\Academics\Numerical Methods\Wavefunction7.txt")
plt.plot(data8[:,0], data8[:,1], label = "$ v = 7$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %% [markdown]
# E8 = -0.2965150E+00

# %%
data9 = np.loadtxt(r"C:\Academics\Numerical Methods\Wavefunction8.txt")
plt.plot(data9[:,0], data9[:,1], label = "$ v = 8$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %% [markdown]
# E9 = -0.2410631E+00

# %%
data10 = np.loadtxt(r"C:\Academics\Numerical Methods\Wavefunction9.txt")
plt.plot(data10[:,0], data10[:,1], label = "$ v = 9$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %% [markdown]
# e10 =--0.1913456E+00

# %%
data11 = np.loadtxt(r"C:\Academics\Numerical Methods\Wavefunction10.txt")
plt.plot(data11[:,0], data11[:,1], label = "$ v = 10$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %% [markdown]
# e11 = -0.1470378E+00

# %%
data12 = np.loadtxt(r"C:\Academics\Numerical Methods\Wavefunction11.txt")
plt.plot(data12[:,0], data12[:,1], label = "$ v = 11$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %% [markdown]
# e12 = -0.1094180E+00

# %%
data13 = np.loadtxt(r"C:\Academics\Numerical Methods\Wavefunction12.txt")
plt.plot(data13[:,0], data13[:,1], label = "$ v = 12$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %% [markdown]
# e13 =  -0.7953787E-01

# %%
data14 = np.loadtxt(r"C:\Academics\Numerical Methods\Wavefunction13 (1).txt")
plt.plot(data14[:,0], data14[:,1], label = "$ v = 13$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %% [markdown]
# e14 = -0.5237278E-01

# %%
data15 = np.loadtxt(r"C:\Academics\Numerical Methods\Wavefunction14.txt")
plt.plot(data15[:,0], data15[:,1], label = "$ v = 14$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %% [markdown]
# e15 = -0.3083810E-01

# %%
data16 = np.loadtxt(r"C:\Academics\Numerical Methods\Wavefunction15.txt")
plt.plot(data16[:,0], data16[:,1], label = "$ v = 15$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %% [markdown]
# e16 = -0.1327256E-01

# %%
data17 = np.loadtxt(r"C:\Academics\Numerical Methods\Wavefunction16.txt")
plt.plot(data17[:,0], data17[:,1], label = "$ v = 16$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %% [markdown]
# e17 = -0.3762543E-02

# %%
data18 = np.loadtxt(r"C:\Users\junai\Fortran\Wavefunction_17.txt")
plt.plot(data18[:,0], data18[:,1], label = "$ v = 17$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %% [markdown]
# e18 = -0.6021063E-04

# %%
data19 = np.loadtxt(r"C:\Academics\Numerical Methods\Wavefunction18.txt")
plt.plot(data19[:,0], data19[:,1], label = "$ v = 18$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(5, 4, figsize=(15, 12))  # Create a 5x4 subplot grid for 19 plots

for i in range(1, 20):
    row = (i - 1) // 4  # Calculate row index
    col = (i - 1) % 4   # Calculate column index

    file_name = rf"C:\Academics\Numerical Methods\Wavefunction{i-1}.txt"  # Assuming file names are Wavefunction1.txt, Wavefunction2.txt, ...
    data = np.loadtxt(file_name)

    axs[row, col].plot(data[:, 0], data[:, 1], label=f"$v = {i - 1}$")
    axs[row, col].set_xlabel("r")
    axs[row, col].set_ylabel('Wavefunctions')
    axs[row, col].grid(True)  # Add grid
    axs[row, col].grid(which='both', linestyle='--', linewidth=0.5, color = "0.9")  # Set grid style

    axs[row, col].minorticks_on()  # Add minor ticks
    axs[row, col].legend()

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Iterations as a function of distance.
# **How can we plot a bar graph of it with distance being the independent variable**

# %%
import matplotlib.pyplot as plt

Guess_bw_0 = [0.9473, 0.9455, 0.9400, 0.9260, 0.9050, 0.8900, 0.8850, 0.8820]
Guess_bw_1 = [0.8468, 0.8402, 0.8302, 0.8192, 0.8042, 0.7952, 0.7922, 0.7902]

energy_0 = 0.9473
energy_1 = 0.8468

dist_0 = [abs(energy_0 - val) for val in Guess_bw_0]
dist_1 = [abs(energy_1 - val) for val in Guess_bw_1]

plt.bar(range(len(dist_0)), dist_0, label='$v = 0$')


plt.xlabel("Number of iteractions")
plt.ylabel('Distance ($|E_{exact} - E_{guess}|$)')
plt.title('Bar Graph of Distances')
plt.legend()
plt.grid(color='grey', alpha = 0.2 )
plt.show()

# %%
import matplotlib.pyplot as plt

Guess_bw_0 = [0.9485, 0.9455, 0.9400, 0.9260, 0.9050, 0.8900, 0.8850, 0.8820]
Guess_bw_1 = [0.8502, 0.8452, 0.8302, 0.8192, 0.8042, 0.7952, 0.7922, 0.7902]

energy_0 = 0.9473
energy_1 = 0.8468

iter_0 = [1, 2, 3, 4, 5, 6, 7, 8]
iter_1 = [1, 2, 3, 4, 5, 6, 7, 8]

dist_0 = [abs(energy_0 - val) for val in Guess_bw_0]
dist_1 = [abs(energy_1 - val) for val in Guess_bw_1]

plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 1)
plt.bar(dist_0, iter_0, width=0.005, label='$v = 0$', color='blue', alpha=0.6)
plt.xlabel("Distance ($|E_{exact} - E_{guess}|$)")
plt.ylabel('Number of iterations')
plt.title('Influence of Distance on Number of Iterations ($v = 0$)')
plt.grid(axis='y')
plt.legend()

plt.subplot(2, 1, 2)
plt.bar(dist_1, iter_1, width=0.005, label='$v = 1$', color='orange', alpha=0.6)
plt.xlabel("Distance ($|E_{exact} - E_{guess}|$)")
plt.ylabel('Number of iterations')
plt.title('Influence of Distance on Number of Iterations ($v = 1$)')
plt.grid(axis='y')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Influence of various parameters

# %%
#-0.9655

r_0 = [0.0, 0.05, 0.10, 0.15, 0.20, 0.25, 0.30, 0.35, 0.40]
iter_r0 = [4, 4, 4, 4, 4, 4, 4, 4, 4]
eig_r0 = [0.9473,0.9473, 0.9473, 0.9473,0.9473,0.9473, 0.9473, 0.9473,0.9473 ]

r_n = [1.0, 1,2, 1.4, 1.6, 1,8, 2.0, 2.4, 2.8, 3.2, 3.6, 4.2 ]
iter_rn = [5,5,4,4,4,4,4,4,4 ]
eig_rn = [0.4022,0.9242 ,0.9459, 0.9471 ,0.9472 ,0.9472,0.9473, 0.9474, 0.9475,0.9476, 0.9478   ]

N = [31, 36, 41, 46, 51, 56, 61, 66, 71, 76, 81]
iter_N = [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4 ]
eig_N = [0.9478,0.9476, 0.9475, 0.9474, 0.9473, 0.9473, 0.9472, 0.9472, 0.9472, 0.9472 ]

eps =[10e-1,10e-2, 10e-3, 10e-4, 10e-5, 10e-6, 10e-7]
iter_eps = [4, 4, 4, 4, 4, 4, 4 ]
eig_eps = [0.9473, 0.9473, 0.9473,0.9473, 0.9473, 0.9473,0.9473, 0.9473]

tol = [10e-1,10e-2, 10e-3, 10e-4, 10e-5, 10e-6, 10e-7]
iter_tol = [1,2,3,4, 4, 4, 5, ]
eig_tol = [0.9655,0.9433,0.9472, 0.9473, 0.9473, 0.9473, 0.9473, ]

# %%
data = np.loadtxt(r"C:\Users\junai\Fortran\E_DE.txt")
plt.figure(figsize=(8, 6))
plt.plot(data[:, 0], data[:, 1], label="$v = 0$", color='blue', linestyle='-')
plt.xlabel('Energy')
plt.ylabel('DE')
plt.title('Energy vs. DE')
plt.ylim(-0.03, 0.25)
plt.xlim(-0.98, None) 
plt.grid(True)
plt.legend()
plt.show()

plt.figure(figsize=(8, 6))
plt.plot(data[:, 0], data[:, 1], label="$v = 0$", color='blue', linestyle='-')
plt.xlabel('Energy')
plt.ylabel('DE')
plt.title('Energy vs. DE')
plt.grid(True)
plt.legend()

plt.ylim(-0.03, 0.1)
plt.xlim(-0.96, None) 

plt.legend()


plt.show()

# %%
data = np.loadtxt(r"C:\Users\junai\Fortran\E_DE_v0.txt")
plt.figure(figsize=(8, 6))
plt.plot(data[:, 0], data[:, 1], label="$v = 0$", color='blue', linestyle='-')
plt.xlabel('Energy')
plt.ylabel('DE')
plt.title('Energy vs. DE')
plt.ylim(-0.03, 0.15)
plt.xlim(-0.98, None) 
plt.grid(True)
plt.legend()
plt.show()

plt.figure(figsize=(8, 6))
plt.plot(data[:, 0], data[:, 1], label="$v = 0$", color='blue', linestyle='-')
plt.xlabel('Energy')
plt.ylabel('DE')
plt.title('Energy vs. DE')
plt.grid(True)
plt.legend()

plt.ylim(-0.03, 0.05)
plt.xlim(-0.966, None) 
# Find the indices where data[:, 1] crosses zero (y-axis)
zero_crossings = np.where(np.diff(np.sign(data[:, 1])))[0]

# Get the x-values corresponding to these zero crossings
interpolated_zeros = []
for idx in zero_crossings:
    x_value = np.interp(0, [data[idx, 1], data[idx + 1, 1]], [data[idx, 0], data[idx + 1, 0]])
    interpolated_zeros.append(x_value)
    plt.scatter(x_value, 0, color='red', marker='o')  # Plot intersection points on the graph
    plt.text(x_value, 0, f'{x_value:.4f}',rotation = 90,  ha='right', va='bottom')  # Annotate intersection points

plt.show()
formatted_values = ["{:.5f}".format(zeros) for zeros in interpolated_zeros]
print(formatted_values)
# Out:
# ['-0.94800', '-0.89982', '-0.84800', '-0.80497', '-0.75600', '-0.71433', '-0.66800', '-0.62923', '-0.58400', '-0.54971', '-0.50800', '-0.47490', '-0.43600', '-0.40611', '-0.36800', '-0.34242', '-0.30800', '-0.28422', '-0.25200', '-0.23130', '-0.20400', '-0.18386']

# %%
import matplotlib.pyplot as plt

Guess_bw_0 = [0.9485, 0.9455, 0.9400, 0.9260, 0.9050, 0.8900, 0.8850, 0.8820]
Guess_bw_1 = [0.8502, 0.8452, 0.8302, 0.8192, 0.8042, 0.7952, 0.7922, 0.7902]
energy_0 = 0.9473
energy_1 = 0.8468

iter_0 = [1, 2, 3, 4, 5, 6, 7, 8]
iter_1 = [1, 2, 3, 4, 5, 6, 7, 8]

dist_0 = [abs(energy_0 - val) for val in Guess_bw_0]
dist_1 = [abs(energy_1 - val) for val in Guess_bw_1]

# Plotting dist_0 vs iter_0
plt.figure(figsize=(8, 6))
plt.scatter(dist_0, iter_0, label='iter_0', color='blue')
plt.xlabel('Distance ($|E_{exact} - E_{guess}|$) for Guess_bw_0')
plt.ylabel('iter_0')
plt.title('Relationship between iter_0 and Distance for Guess_bw_0')
plt.grid(True)
plt.legend()
plt.show()

# Plotting dist_1 vs iter_1
plt.figure(figsize=(8, 6))
plt.scatter(dist_1, iter_1, label='iter_1', color='red')
plt.xlabel('Distance ($|E_{exact} - E_{guess}|$) for Guess_bw_1')
plt.ylabel('iter_1')
plt.title('Relationship between iter_1 and Distance for Guess_bw_1')
plt.grid(True)
plt.legend()
plt.show()

# %%
data = np.loadtxt(r"C:\Users\junai\Fortran\R0_Energ_Ncount.txt")
plt.figure(figsize=(8, 6))
plt.plot(data[:, 0], data[:, 1], color='blue', linestyle='-')
plt.xlabel('R0')
plt.ylabel('Eigenvalue')
plt.ylim(-1, -0.85)
plt.title("Variation of eigenvalues with R0") 
plt.grid(True)
plt.show()

# %%
data = np.loadtxt(r"C:\Users\junai\Fortran\R0_Energ_Ncount.txt")
plt.figure(figsize=(8, 6))
plt.plot(data[:, 0], data[:, 2], color='blue', linestyle='-')
plt.xlabel('R0')
plt.ylabel('Iterations ')
plt.title("Variation of Iterations with R0") 
plt.ylim(0, 8)
plt.grid(True)
plt.show()

# %%
data = np.loadtxt(r"C:\Users\junai\Fortran\RN_Energ_Ncount.txt")
plt.figure(figsize=(8, 6))
plt.plot(data[:, 0], data[:, 1], color='blue', linestyle='-')
plt.xlabel('RN')
plt.ylabel('Eigenvalue')
plt.ylim(-1, -0.8)
plt.title("Variation of eigenvalues with RN") 
plt.grid(True)
plt.show()

# %%
data = np.loadtxt(r"C:\Users\junai\Fortran\RN_Energ_Ncount.txt")
plt.figure(figsize=(8, 6))
plt.plot(data[:, 0], data[:, 2], color='blue', linestyle='-')
plt.xlabel('RN')
plt.ylabel('Iterations')
plt.title("Variation of Iterations with RN") 
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
N = [31, 36, 41, 46, 51, 56, 61, 66, 71, 76, 81]
iter_N = [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4]
eig_N = [-0.9478, -0.9476, -0.9475, -0.9474, -0.9473, -0.9473, -0.9472, -0.9472, -0.9472, -0.9472]

# Create line plots with markers for N on x-axis
plt.figure(figsize=(8, 5))

# Line plot for iter_N
plt.plot(N, iter_N, marker='o', linestyle='-', label='Iterations')

# Set labels, title, legend, and grid
plt.xlabel('Number of steps')
plt.ylabel('Iterations')
plt.title('Variation of the iterations with number of the steps')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Line plot for eig_N
plt.plot(N[0:10], eig_N, marker='*', linestyle='--', label='Eigenvalues')
# Set labels, title, legend, and grid
plt.xlabel('Number of steps')
plt.ylabel('Eigenvalue')
plt.title('Variation of the iterations with number of the steps')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Variation with eps
data = np.loadtxt(r"C:\Users\junai\Fortran\EPS_Energ_Ncount.txt")
x = np.array(data[:, 0])
plt.figure(figsize=(8, 6))
plt.semilogx(x, data[:, 1], color='blue', linestyle='-', marker = "*")
plt.xlabel('EPS(Log scale)')
plt.ylabel('Eigenvalue')
plt.ylim(-1, -0.8)
plt.title("Variation of eigenvalues with EPS") 
plt.grid(True)
plt.show()
print(data[:, 0])
# Out:
# [1.e-10 1.e-09 1.e-08 1.e-07 1.e-06 1.e-05 1.e-04 1.e-03 1.e-02 1.e-01]

# %%
# Variation with eps
data = np.loadtxt(r"C:\Users\junai\Fortran\EPS_Energ_Ncount.txt")
plt.figure(figsize=(8, 6))
plt.semilogx(data[:, 0], data[:, 2], color='blue', linestyle='-', marker = "*")
plt.xlabel('EPS')
plt.ylabel('Iterations')
plt.title("Variation of Iterations with EPS") 
plt.grid(True)
plt.show()

# %%
# Variation with tolerance
data = np.loadtxt(r"C:\Users\junai\Fortran\TOL_Energ_Ncount.txt")
plt.figure(figsize=(8, 6))
plt.semilogx(data[:, 0], data[:, 1], color='blue', linestyle='-', marker = "*")
plt.xlabel('Tol(Log scale)')
plt.ylabel('Eigenvalue')
plt.ylim(-0.98, -0.92)
plt.xlim(1e-9, 1)
plt.title("Variation of eigenvalues with TOL") 
plt.grid(True)
plt.show()

# %%
data = np.loadtxt(r"C:\Users\junai\Fortran\TOL_Energ_Ncount.txt")
plt.figure(figsize=(8, 6))
plt.semilogx(data[:, 0], data[:, 2], color='blue', linestyle='-', marker = "*")
plt.xlabel('Tol(Log scale)')
plt.ylabel('Iterations')
plt.xlim(1e-9, 1)
plt.title("Variation of iterations with TOL") 
plt.grid(True)
plt.show()

# %%
## For higher eigenvalues
data = np.loadtxt(r"C:\Users\junai\Fortran\R0_Energ_Ncount_12.txt")
plt.figure(figsize=(8, 6))
plt.plot(data[:, 0], data[:, 1], color='blue', linestyle='-', label = "v = 12")
plt.xlabel('R0')

plt.ylabel('Eigenvalue')
plt.title("Variation of eigenvalues with R0") 
plt.grid(True)
plt.legend()
plt.show()

# %%
data = np.loadtxt(r"C:\Users\junai\Fortran\R0_Energ_Ncount_12.txt")
plt.figure(figsize=(8, 6))
plt.plot(data[:, 0], data[:, 2], color='blue', linestyle='-', label = "v = 12")
plt.xlabel('R0')
plt.ylabel('iterations')
plt.title("Variation of Iterations with R0") 
plt.grid(True)
plt.legend()
plt.show()

# %%
data = np.loadtxt(r"C:\Users\junai\Fortran\RN_Energ_Ncount_12.txt")
plt.figure(figsize=(8, 6))
plt.plot(data[:, 0], data[:, 1], color='blue', linestyle='-', label = "v = 12")
plt.xlabel('RN')
plt.ylim(-0.110, -0.108)
plt.ylabel('Eigenvalue')
plt.title("Variation of eigenvalues with RN") 
plt.grid(True)
plt.legend()
plt.show()

# %%
data = np.loadtxt(r"C:\Users\junai\Fortran\RN_Energ_Ncount_12.txt")
plt.figure(figsize=(8, 6))
plt.plot(data[:, 0], data[:, 2], color='blue', linestyle='-', label = "v = 12")
plt.xlabel('RN')
plt.ylim(0, 8)
plt.ylabel('iterations')
plt.title("Variation of Iterations with RN") 
plt.grid(True)
plt.legend()
plt.show()

# %%
data = np.loadtxt(r"C:\Users\junai\Fortran\N_energy_iter_v12.txt")
plt.figure(figsize=(8, 6))
plt.plot(data[:, 0], data[:, 2], color='blue', linestyle='-', label = "v = 12")
plt.xlabel('Number of steps')
plt.ylabel('Eigenvalue')
plt.title("Variation of eigenvalues with N steps") 
plt.grid(True)
plt.legend()
plt.show()

# %%
data = np.loadtxt(r"C:\Users\junai\Fortran\N_energy_iter_v12.txt")
plt.figure(figsize=(8, 6))
plt.plot(data[:, 0], data[:, 1], color='blue', linestyle='-', label = "v = 12")
plt.xlabel('Number of steps')
plt.ylim(0, 8)
plt.ylabel('Iterations')
plt.title("Variation of Iterations with N steps") 
plt.grid(True)
plt.legend()
plt.show()

# %%
data = np.loadtxt(r"C:\Users\junai\Fortran\TOL_Energ_Ncount_12.txt")
x = np.array(data[:, 0])
plt.figure(figsize=(8, 6))
plt.semilogx(x, data[:, 1], color='blue', linestyle='-', marker = "*", label = "v = 12")
plt.xlabel('TOL(Log scale)')
plt.ylabel('Eigenvalue')
plt.title("Variation of eigenvalues with TOL") 
plt.grid(True)
plt.show()

# %%
data = np.loadtxt(r"C:\Users\junai\Fortran\TOL_Energ_Ncount_12.txt")
x = np.array(data[:, 0])
plt.figure(figsize=(8, 6))
plt.semilogx(x, data[:, 2], color='blue', linestyle='-', marker = "*", label = "v = 12")
plt.xlabel('TOL(Log scale)')
plt.ylabel('Iterations')
plt.title("Variation of Iterations with TOL") 
plt.xticks(x)
plt.grid(True)
plt.show()

# %%
data = np.loadtxt(r"C:\Users\junai\Fortran\EPS_Energ_Ncount_12.txt")
x = np.array(data[:, 0])
plt.figure(figsize=(8, 6))
plt.semilogx(x, data[:, 1], color='blue', linestyle='-', marker = "*", label = "v = 12")
plt.xlabel('EPS(Log scale)')
plt.ylabel('Eigenvalue')
plt.title("Variation of eigenvalues with EPS") 
plt.grid(True)
plt.show()

# %%
data = np.loadtxt(r"C:\Users\junai\Fortran\EPS_Energ_Ncount_12.txt")
x = np.array(data[:, 0])
plt.figure(figsize=(8, 6))
plt.semilogx(x, data[:, 2], color='blue', linestyle='-', marker = "*", label = "v = 12")
plt.xlabel('EPS(Log scale)')
plt.ylabel('Iterations')
plt.title("Variation of Iterations with EPS") 
plt.grid(True)
plt.show()

# %%
# Increased N points
data = np.loadtxt(r"C:\Users\junai\Fortran\Wavefunction_0_int.txt")
plt.plot(data[:,0], data[:,1], label = "$v = 0$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %%
data = np.loadtxt(r"C:\Users\junai\Fortran\Wavefunction_1_int.txt")
plt.plot(data[:,0], data[:,1], label = "$v = 1$")
plt.xlabel("r")
plt.ylabel('wave function')
plt.legend()
plt.show()

# %%
from scipy import integrate
B=60.8
wave_0 =np.loadtxt(r"C:\Users\junai\Fortran\Wavefunction_0_int.txt")

x_0=wave_0[:,0]
y_0=wave_0[:,1]

r_0=x_0**(-2)


wave_1 = np.loadtxt(r"C:\Users\junai\Fortran\Wavefunction_1_int.txt")
x_1 = wave_1[:,0]
y_1 = wave_1[:,1]
r_1 = x_1**(-2)

# calculation of the Normalisation coefficient:
coeff_0 = integrate.simpson(y_0**2, x_0)
coeff_1 = integrate.simpson(y_1**2, x_1)

# Calculation of the integration in order to get B_0 and B_1
f_0=y_0**2*r_0/coeff_0
i_0=integrate.simpson(f_0, x_0)

f_1=y_1**2*r_1/coeff_1
i_1=integrate.simpson(f_1, x_1)

B_0=B*i_0
B_1=B*i_1

print(f"B0 is {B_0} and B1 is {B_1}")
# Out:
# B0 is 59.81418210929073 and B1 is 57.7054955279155

# %%
import numpy as np

B = 60.8

# Load data from files
wave_0 = np.loadtxt(r"C:\Users\junai\Fortran\Wavefunction_0_int.txt")
x_0 = wave_0[:, 0]
y_0 = wave_0[:, 1]
r_0 = x_0**(-2)

wave_1 = np.loadtxt(r"C:\Users\junai\Fortran\Wavefunction_1_int.txt")
x_1 = wave_1[:, 0]
y_1 = wave_1[:, 1]
r_1 = x_1**(-2)

# Calculation of the Normalization coefficients
coeff_0 = np.sum(y_0**2)
coeff_1 = np.sum(y_1**2)

# Calculation of the integration in order to get B_0 and B_1
f_0 = y_0**2 * r_0 / coeff_0
i_0 = np.sum(f_0)

f_1 = y_1**2 * r_1 / coeff_1
i_1 = np.sum(f_1)

B_0 = B * i_0
B_1 = B * i_1

print(f"B0 is {B_0} and B1 is {B_1}")
# Out:
# B0 is 59.83038228034036 and B1 is 57.705492685407165

# %% [markdown]
# #### Question 6.
# $E_{v, j}^{0} = E_{o} + BJ(J+1)$
# B = bV0

# %%
V0 = 40970.35
E_act = -0.9470
E_j = -0.9441
J = 1
b = (E_act - E_j)/(J*(J + 1))
B =  b * V0
print(B)
# Out:
# -59.407007499998

# %%
V0 = 40970.35
E_act = -0.9470
E_j = -0.9383
J = 2
b = (E_act - E_j)/(J*(J + 1))
B =  b * V0
print(B)
# Out:
# -59.40700749999952

# %%
V0 = 40970.35
E_act = -0.9470
E_j = -0.9297
J = 3
b = (E_act - E_j)/(J*(J + 1))
B =  b * V0
print(B)
# Out:
# -59.0655879166666

# %%
V0 = 40970.35
E_act = -0.9470
E_j = -0.9183
J = 4
b = (E_act - E_j)/(J*(J + 1))
B =  b * V0
print(B)
# Out:
# -58.7924522499999

# %%
V0 = 40970.35
E_act = -0.9470
E_j = -0.9043
J = 5
b = (E_act - E_j)/(J*(J + 1))
B =  b * V0
print(B)
# Out:
# -58.314464833333275

# %%
E_values = [-0.8428, -0.8372, -0.8289, -0.8179, -0.8044]
E_0 = -0.8456
V0 = 40970.35

for x in range(1, len(E_values) + 1):
    b = (E_0 - E_values[x - 1]) / (x * (x + 1))
    B = b * V0
    print(f"Value for x = {x}: {B}")

# What kind of shit is this that i could not do this code on my own, this little code
# Out:
# Value for x = 1: -57.3584900000005
# Value for x = 2: -57.35848999999975
# Value for x = 3: -57.017070416666826
# Value for x = 4: -56.74393475000012
# Value for x = 5: -56.26594733333335

# %%
V0 = 40970.35
E_act = -0.8456
E_j = -0.8428
J = 1
b = (E_act - E_j)/(J*(J + 1))
B =  b * V0
print(B)
# Out:
# -57.3584900000005

# %% [markdown]
# Comparison with the theoritical values using more potential

# %%
import numpy as np
a = 1.3924
b = 1.4840e-3
energy = []
for i in range(19):
    e = -(1 - a*np.sqrt(b)*(i + 0.5))**2
    print(f"eigenvalue {i} = {e:.7f}")
    energy.append(e)
    
print(energy)
# Out:
# eigenvalue 0 = -0.9470803
# eigenvalue 1 = -0.8455565
# eigenvalue 2 = -0.7497870
# eigenvalue 3 = -0.6597718
# eigenvalue 4 = -0.5755109
# eigenvalue 5 = -0.4970043
# eigenvalue 6 = -0.4242520
# eigenvalue 7 = -0.3572539
# eigenvalue 8 = -0.2960102
# eigenvalue 9 = -0.2405208
# eigenvalue 10 = -0.1907856
# eigenvalue 11 = -0.1468048
# eigenvalue 12 = -0.1085782
# eigenvalue 13 = -0.0761059
# eigenvalue 14 = -0.0493879
# eigenvalue 15 = -0.0284243
# eigenvalue 16 = -0.0132149
# eigenvalue 17 = -0.0037598
# eigenvalue 18 = -0.0000589
# [-0.9470802504293576, -0.8455564705818333, -0.7497869831259883, -0.659771788061824, -0.5755108853893393, -0.4970042751085348, -0.42425195721941, -0.35725393172196557, -0.2960101986162008, -0.24052075790211636, -0.19078560957971166, -0.14680475364898715, -0.10857819010994248, -0.07610591896257796, -0.0493879402068933, -0.028424253842888752, -0.013214859870564127, -0.0037597582899195547, -5.8949100954955266e-05]
